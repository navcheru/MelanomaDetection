# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# 2024-09-18 18:26:28.577685: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("data/Train")
data_dir_test = pathlib.Path('data/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %% [markdown]
# # Set up the data generators for training and testing
# train_datagen = ImageDataGenerator(rescale=1.0/255.0)
# test_datagen = ImageDataGenerator(rescale=1.0/255.0)

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
# Visualizing classes

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(len(class_names)):
        ax = plt.subplot(3, 3, i + 1)
        plt.title(class_names[labels[i]])
        plt.axis("off")
        plt.imshow(images[i].numpy().astype("uint8"))

### your code goes here, you can use training or validation data to visualize
# Out:
# 2024-09-17 23:30:19.896613: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
from tensorflow.keras import layers, Sequential

classes = len(class_names)  # Number of classes
img_height = 180
img_width = 180

# Build the model
model_1 = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(classes)  # No activation here, as it's added later during compilation
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model_1.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])

# %%
# View the summary of all layers
model_1.summary()
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_14 (Rescaling)        │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_45 (Conv2D)              │ (None, 180, 180, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_45 (MaxPooling2D) │ (None, 90, 90, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_46 (Conv2D)              │ (None, 90, 90, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_46 (MaxPooling2D) │ (None, 45, 45, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_47 (Conv2D)              │ (None, 45, 45, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_47 (MaxPooling2D) │ (None, 22, 22, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_14 (Flatten)            │ (None, 30976)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 128)            │     3,965,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 9)              │         1,161 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,989,801 (15.22 MB)
#  Trainable params: 3,989,801 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %%
# Default batch size in keras is 32 .So I am not mentioned it explicitly

# %%
epochs = 20
history_1 = model_1.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 20s 278ms/step - accuracy: 0.2042 - loss: 2.2762 - val_accuracy: 0.3915 - val_loss: 1.7610
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 273ms/step - accuracy: 0.3874 - loss: 1.7201 - val_accuracy: 0.4116 - val_loss: 1.6234
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 273ms/step - accuracy: 0.4397 - loss: 1.5488 - val_accuracy: 0.5257 - val_loss: 1.4357
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 290ms/step - accuracy: 0.5499 - loss: 1.3193 - val_accuracy: 0.5391 - val_loss: 1.3710
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 276ms/step - accuracy: 0.5629 - loss: 1.2080 - val_accuracy: 0.4676 - val_loss: 1.7868
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 279ms/step - accuracy: 0.5995 - loss: 1.1576 - val_accuracy: 0.5436 - val_loss: 1.3995
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 273ms/step - accuracy: 0.6237 - loss: 1.0580 - val_accuracy: 0.5324 - val_loss: 1.4603
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 285ms/step - accuracy: 0.6626 - loss: 0.9430 - val_accuracy: 0.5481 - val_loss: 1.5180
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 276ms/step - accuracy: 0.6904 - loss: 0.8719 - val_accuracy: 0.5213 - val_loss: 1.5824
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 270ms/step - accuracy: 0.6998 - loss: 0.8369 - val_accuracy: 0.4989 - val_loss: 1.5640
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 279ms/step - accuracy: 0.7188 - loss: 0.7934 - val_accuracy: 0.4810 - val_loss: 1.6698
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 295ms/step - accuracy: 0.7545 - loss: 0.7022 - val_accuracy: 0.5391 - val_loss: 1.8191
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 275ms/step - accuracy: 0.8043 - loss: 0.5482 - val_accuracy: 0.5459 - val_loss: 1.8265
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 281ms/step - accuracy: 0.8400 - loss: 0.4552 - val_accuracy: 0.5391 - val_loss: 1.7759
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 290ms/step - accuracy: 0.8296 - loss: 0.4387 - val_accuracy: 0.5123 - val_loss: 1.9705
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 282ms/step - accuracy: 0.8437 - loss: 0.3991 - val_accuracy: 0.5078 - val_loss: 2.2779
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 290ms/step - accuracy: 0.8603 - loss: 0.3871 - val_accuracy: 0.5145 - val_loss: 2.3410
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.8799 - loss: 0.3239 - val_accuracy: 0.5302 - val_loss: 2.6702
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 293ms/step - accuracy: 0.8751 - loss: 0.2954 - val_accuracy: 0.5123 - val_loss: 2.6662
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - accuracy: 0.9003 - loss: 0.2510 - val_accuracy: 0.5459 - val_loss: 2.3866

# %% [markdown]
# ### Visualizing training results

# %%
acc = history_1.history['accuracy']
val_acc = history_1.history['val_accuracy']

loss = history_1.history['loss']
val_loss = history_1.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Observations from the plots:
#
# * **Training Accuracy & Loss:**
#     - Training accuracy steadily increases over epochs, reaching a high value.
#     - Training loss consistently decreases.
#
# * **Validation Accuracy & Loss:**
#     - Validation accuracy increases initially but then plateaus or even starts to slightly decrease towards the end.
#     - Validation loss decreases initially but then starts to increase or fluctuate.
#
# ### Interpretation & Findings:
#
# These patterns suggest that the model is likely **overfitting**. Here’s why:
#
# * The gap between training and validation accuracy is widening towards the later epochs. This indicates that the model is learning to perform very well on the training data, potentially memorizing it, but it's not generalizing well to new, unseen data (the validation set).
# * The increasing validation loss further confirms this. The model is getting worse at predicting on the validation set, even though it continues to improve on the training set.
#
#
# ### Potential Solutions to Address Overfitting:
#
# * **Get more training data:** More data can help the model learn more general patterns
# * **Data Augmentation:** Artificially increase the size and diversity of your training set by applying random transformations.
# * **Regularization techniques:**
#     * L1 or L2 regularization to penalize large weights in the model
#     * Dropout to randomly drop neurons during training
# * **Early Stopping:** Stop training when validation loss starts to increase.
# * **Reduce model complexity:** If the model is too complex for the given data, simplify it by reducing the number of layers or neurons.

# %% [markdown]
# ### Write your findings here

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
# Define model parameters
img_height = 180
img_width = 180
num_classes = len(class_names)

# Build the CNN model with dropout and L2 regularization
model_2 = models.Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.MaxPooling2D(),
    layers.Dropout(0.3),
    layers.Conv2D(128, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.MaxPooling2D(),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    layers.Dropout(0.2),
    layers.Dense(num_classes, activation='softmax')
])

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 180, 180, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 90, 90, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 90, 90, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 90, 90, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 45, 45, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 45, 45, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 45, 45, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 22, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 61952)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │    15,859,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,955,529 (60.87 MB)
#  Trainable params: 15,955,529 (60.87 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

# Compile the model
model_2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history_2 = model_2.fit(
    train_ds,
    epochs=20,
    validation_data=val_ds
)
# Out:
# Epoch 1/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 39s 665ms/step - accuracy: 0.1774 - loss: 9.3928 - val_accuracy: 0.2058 - val_loss: 4.0882
# Epoch 2/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 38s 685ms/step - accuracy: 0.2129 - loss: 3.7136 - val_accuracy: 0.1924 - val_loss: 3.1320
# Epoch 3/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 724ms/step - accuracy: 0.1849 - loss: 2.9905 - val_accuracy: 0.2304 - val_loss: 2.7548
# Epoch 4/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.2272 - loss: 2.6921 - val_accuracy: 0.2192 - val_loss: 2.5765
# Epoch 5/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 54s 973ms/step - accuracy: 0.2279 - loss: 2.5392 - val_accuracy: 0.2685 - val_loss: 2.4538
# Epoch 6/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 53s 947ms/step - accuracy: 0.2616 - loss: 2.3961 - val_accuracy: 0.2886 - val_loss: 2.3940
# Epoch 7/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 56s 998ms/step - accuracy: 0.2426 - loss: 2.3794 - val_accuracy: 0.2796 - val_loss: 2.2994
# Epoch 8/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 49s 876ms/step - accuracy: 0.2464 - loss: 2.2957 - val_accuracy: 0.2774 - val_loss: 2.2792
# Epoch 9/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 52s 938ms/step - accuracy: 0.2626 - loss: 2.2436 - val_accuracy: 0.3311 - val_loss: 2.1564
# Epoch 10/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 52s 922ms/step - accuracy: 0.3011 - loss: 2.1724 - val_accuracy: 0.2953 - val_loss: 2.1592
# Epoch 11/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 51s 920ms/step - accuracy: 0.3232 - loss: 2.0949 - val_accuracy: 0.3132 - val_loss: 2.1009
# Epoch 12/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 51s 911ms/step - accuracy: 0.3205 - loss: 2.0803 - val_accuracy: 0.3065 - val_loss: 2.0473
# Epoch 13/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 53s 948ms/step - accuracy: 0.3548 - loss: 1.9688 - val_accuracy: 0.3736 - val_loss: 1.8957
# Epoch 14/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 52s 933ms/step - accuracy: 0.3902 - loss: 1.9376 - val_accuracy: 0.3937 - val_loss: 1.8578
# Epoch 15/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.4209 - loss: 1.8344 - val_accuracy: 0.4631 - val_loss: 1.7656
# Epoch 16/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.4177 - loss: 1.7791 - val_accuracy: 0.4497 - val_loss: 1.7747
# Epoch 17/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.4360 - loss: 1.7538 - val_accuracy: 0.4631 - val_loss: 1.7047
# Epoch 18/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 56s 998ms/step - accuracy: 0.4473 - loss: 1.7158 - val_accuracy: 0.4430 - val_loss: 1.7110
# Epoch 19/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 51s 919ms/step - accuracy: 0.4548 - loss: 1.6519 - val_accuracy: 0.4765 - val_loss: 1.6476
# Epoch 20/20
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 53s 941ms/step - accuracy: 0.4711 - loss: 1.6520 - val_accuracy: 0.4877 - val_loss: 1.6661

# %% [markdown]
# ### Visualizing the results

# %%
acc = history_2.history['accuracy']
val_acc = history_2.history['val_accuracy']

loss = history_2.history['loss']
val_loss = history_2.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# # Findings from Epoch Logs:
#
# ### Training and Validation Accuracy:
# ### - The training accuracy starts at a low value of 17.74% in the first epoch and steadily increases to 47.11% by the 20th epoch.
# ### - The validation accuracy follows a similar pattern, starting at 20.58% and improving to 48.77%.
# ### - The steady increase in both training and validation accuracy without a large discrepancy between them indicates no signs of overfitting.
# ###   The model generalizes well and improves as training progresses.
#
# ### Training and Validation Loss:
# ### - The training loss starts high at 9.39 and decreases to 1.65 by the 20th epoch.
# ### - The validation loss similarly reduces from 4.09 to 1.66.
# ### - The close tracking of validation loss and training loss indicates that the model is not underfitting and is
# ###   There is a good correlation between reducing loss and improving accuracy.
#
# # Comparison to Previous Runs:
# ### - This model shows substantial improvement compared to the initial epochs, where both accuracy and loss were much worse.
# ### The model now demonstrates the ability to learn effectively and improve over time.
#
# # No Overfitting:
# ### - Since there is no large divergence between the training and validation accuracy or loss, overfitting does not seem to be an issue.
# ###   The model can be trained for a few more epochs to see if further improvements are possible.
#
# # Potential Further Improvements:
# # - Continue Training: Since accuracy is still improving by the 20th epoch, additional epochs could help further enhance performance.
# # - Fine-tune Model Architecture: Consider experimenting with deeper layers, or adjustments to the optimizer or learning rate to see if performance can be further optimized.
#
# # Conclusion:
# # - The model is showing good progress and significant improvement compared to earlier runs.
# # - No signs of overfitting or underfitting are observed, and the model continues to generalize well.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import pathlib
import pandas as pd

# Define the directory paths
data_dir_train = pathlib.Path("data/Train")

# Get the class names from the directory structure
class_names = [d.name for d in data_dir_train.iterdir() if d.is_dir()]

# Initialize an empty list to store class counts
class_counts = []

# Count the number of images in each class directory
for class_name in class_names:
    class_path = data_dir_train / class_name
    num_images = len(list(class_path.glob('*.jpg')))
    class_counts.append({'class': class_name, 'number': num_images})

# Create a DataFrame from the list of class counts
class_diff = pd.DataFrame(class_counts)

# Display the class distribution
print(class_diff)
# Out:
#                         class  number
# 0                    melanoma     438
# 1  pigmented benign keratosis     462
# 2                       nevus     357
# 3        basal cell carcinoma     376
# 4           actinic keratosis     114
# 5     squamous cell carcinoma     181
# 6             vascular lesion     139
# 7        seborrheic keratosis      77
# 8              dermatofibroma      95

# %% [markdown]
# **Class Imbalance Analysis**
# ==========================
#
# ### Findings:
#
# * Majority class: Pigmented benign keratosis (462 samples, 22.1%)
# * Minority class: Seborrheic keratosis (77 samples, 3.7%)
# * Class imbalance ratio: 6:1 (majority/minority)
#
# ### Next Step:
#
# 1. Apply class weighting or oversampling to minority classes.
# 2. Consider undersampling majority classes.
# 3. Use data augmentation to increase minority class samples.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming `class_diff` is a DataFrame or dictionary with 'class' and 'number' keys

# Generate a color for each class
colors = plt.cm.get_cmap('tab20', len(class_diff['class']))  # 'tab20' colormap with unique colors for each class

# Plot the class distribution
plt.figure(figsize=(12, 6))
plt.bar(class_diff['class'], class_diff['number'], color=[colors(i) for i in np.arange(len(class_diff['class']))])

# Add labels and title
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Distribution of Images per Class')
plt.xticks(rotation=45, ha='right')  # Rotate class names for better readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/wz/1hfqkpsj4xzfkhmb44n3vvc80000gn/T/ipykernel_1529/1137892071.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab20', len(class_diff['class']))  # 'tab20' colormap with unique colors for each class

# %% [markdown]
# #### **Todo:** Write your findings here:
#
# #### - Which class has the least number of samples?
# ###### Answer: Seborrheic keratosis (77 samples)
#
# #### - Which classes dominate the data in terms of proportionate number of samples?
# ###### Answer: Pigmented benign keratosis (462 samples, 22.1%) and Melanoma (438 samples, 20.9%)

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Obtaining dependency information for Augmentor from https://files.pythonhosted.org/packages/f3/86/5a91176650eb229ea2cd95551c34c36fba6cd95da3bdc4a5c73fbb1536ca/Augmentor-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /Users/kajalmahata/anaconda3/lib/python3.11/site-packages (from Augmentor) (10.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /Users/kajalmahata/anaconda3/lib/python3.11/site-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /Users/kajalmahata/anaconda3/lib/python3.11/site-packages (from Augmentor) (1.24.3)
# Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="data/Train/"
import Augmentor
for i in class_names:
    print(path_to_training_dataset + i)
    p = Augmentor.Pipeline(path_to_training_dataset + i,output_directory="/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/"+i+"/")
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# data/Train/melanoma
# Initialised with 438 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x
# data/Train/pigmented benign keratosis
# Initialised with 462 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/pigmented benign keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x147B4C150>: 100%|█|
# data/Train/nevus
# Initialised with 357 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/nevus/.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x147439C10>: 100%|█|
# data/Train/basal cell carcinoma
# Initialised with 376 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/basal cell carcinoma/.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1
# data/Train/actinic keratosis
# Initialised with 114 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/actinic keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x148D65110>: 100%|█|
# data/Train/squamous cell carcinoma
# Initialised with 181 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/squamous cell carcinoma/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x147AB65D0>: 100%|█|
# data/Train/vascular lesion
# Initialised with 139 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/vascular lesion/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x148E43C10>: 100%|█|
# data/Train/seborrheic keratosis
# Initialised with 77 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/seborrheic keratosis/.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x148027A90>: 100%|█
# data/Train/dermatofibroma
# Initialised with 95 image(s) found.
# Output directory set to /Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/dermatofibroma/.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x13ECE9D90>: 100%|█|

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train_aug = pathlib.Path("/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented")
image_count_train = len(list(data_dir_train_aug.glob('**/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
data_dir_train_aug = pathlib.Path('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data')
path_list_new = list(data_dir_train_aug.rglob('augmented/*/*.jpg'))
print(path_list_new)
# Out:
# [PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000554.jpg_cf3e3d53-8e36-4e7f-8a20-24ad2b6edef1.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000294.jpg_ab6af446-b582-44b5-b08d-e6b16b10dd8f.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000163.jpg_edf9fe39-7f9c-4102-bf9d-526fca1cbb23.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010081.jpg_6cf014ae-ce5e-4bbc-89be-bd813a26ef25.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010106.jpg_4b1d5f9b-4c1d-4cb1-a52d-29fafa7c5bbb.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0011169.jpg_32e2306e-4e02-474b-ae06-780e130534d2.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010591.jpg_5dae4854-b419-45d4-ba87-a60fde6b8c10.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0001125.jpg_df9cc32e-78fe-4576-b9f8-3922786cfede.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010171.jpg_5b229683-ddb9-4f4e-9973-f15e736d4fbc.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010131.jpg_4f4fe3a3-4727-4878-99ee-4c931d5fbe29.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000306.jpg_12446ff9-765c-4844-b240-3d451d8fd45a.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010754.jpg_3a68c4a4-8ce2-4bc8-a26e-501c99fdd8ba.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010468.jpg_57c51271-4d7b-42ca-8a34-4dcf0c578195.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010049.jpg_05ca7897-905c-41e9-80ca-f49451621e05.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0009992.jpg_e77d38e8-93bb-4038-a61b-31ef2585e847.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0010979.jpg_37d72d11-cf17-4305-b016-ca32e322ff2c.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000169.jpg_6b97dc7a-59ee-42f4-970f-a18942c4012b.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000162.jpg_bc95186d-d619-4567-b94c-a1eaf8798343.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000310.jpg_8b498c06-7568-4111-b30a-262174ad781c.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/melanoma_original_ISIC_0000296.jpg_803c0373-6dfa-4cf1-99cc-c7e726533a64.jpg'), PosixPath('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented/melanoma/mela ...

# %%
from glob import glob
dir_train_aug = pathlib.Path('/Users/kajalmahata/Desktop/IIITB/Machine Learning/Assignment/melanoma-detection/data/augmented')

path_list = [x for x in glob(os.path.join(dir_train_aug, '*', '*.jpg'))]
lesion_list_new = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(dir_train_aug, '*', '*.jpg'))]
lesion_list_new
# Out:
# ['melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  'pigmented benign keratosis',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = df2

# %%
new_df['Label'].value_counts()
# Out:
# Label
# melanoma                      500
# pigmented benign keratosis    500
# nevus                         500
# basal cell carcinoma          500
# actinic keratosis             500
# squamous cell carcinoma       500
# vascular lesion               500
# seborrheic keratosis          500
# dermatofibroma                500
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
class_names
# Out:
# ['melanoma',
#  'pigmented benign keratosis',
#  'nevus',
#  'basal cell carcinoma',
#  'actinic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion',
#  'seborrheic keratosis',
#  'dermatofibroma']

# %%
data_dir_train='data/augmented/'
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
from tensorflow.keras import layers, Sequential

classes = len(class_names)  # Number of classes
img_height = 180
img_width = 180

# Build the model
model_3 = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(16, activation='relu'),
  layers.Dense(classes,activation='softmax')  # No activation here, as it's added later during compilation
])
# Out:
# /Users/kajalmahata/anaconda3/lib/python3.11/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compiling the model
model_3.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model_3.summary()
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_16 (Rescaling)        │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_51 (Conv2D)              │ (None, 180, 180, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_51 (MaxPooling2D) │ (None, 90, 90, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_52 (Conv2D)              │ (None, 90, 90, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_52 (MaxPooling2D) │ (None, 45, 45, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_53 (Conv2D)              │ (None, 45, 45, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_53 (MaxPooling2D) │ (None, 22, 22, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 15488)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 16)             │       247,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_39 (Dense)                │ (None, 9)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 343,817 (1.31 MB)
#  Trainable params: 343,817 (1.31 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training the model
epochs = 30
history_3 = model_3.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 227s 2s/step - accuracy: 0.1087 - loss: 2.2040 - val_accuracy: 0.1056 - val_loss: 2.1973
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.1092 - loss: 2.1974 - val_accuracy: 0.1056 - val_loss: 2.1973
# Epoch 3/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.1060 - loss: 2.1974 - val_accuracy: 0.1056 - val_loss: 2.1975
# Epoch 4/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.1099 - loss: 2.1973 - val_accuracy: 0.1056 - val_loss: 2.1975
# Epoch 5/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.1137 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1976
# Epoch 6/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.1048 - loss: 2.1974 - val_accuracy: 0.1056 - val_loss: 2.1977
# Epoch 7/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.1133 - loss: 2.1975 - val_accuracy: 0.1056 - val_loss: 2.1977
# Epoch 8/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 21686s 194s/step - accuracy: 0.1118 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1977
# Epoch 9/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.1085 - loss: 2.1973 - val_accuracy: 0.1067 - val_loss: 2.1978
# Epoch 10/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - accuracy: 0.1076 - loss: 2.1973 - val_accuracy: 0.1056 - val_loss: 2.1978
# Epoch 11/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.1140 - loss: 2.1975 - val_accuracy: 0.1056 - val_loss: 2.1978
# Epoch 12/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.1146 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1978
# Epoch 13/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.1038 - loss: 2.1974 - val_accuracy: 0.1056 - val_loss: 2.1978
# Epoch 14/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.1152 - loss: 2.1974 - val_accuracy: 0.1011 - val_loss: 2.1979
# Epoch 15/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.1208 - loss: 2.1974 - val_accuracy: 0.1011 - val_loss: 2.1979
# Epoch 16/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.1126 - loss: 2.1974 - val_accuracy: 0.1011 - val_loss: 2.1979
# Epoch 17/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 220s 2s/step - accuracy: 0.1227 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 18/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 218s 2s/step - accuracy: 0.1111 - loss: 2.1973 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 19/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 254s 2s/step - accuracy: 0.1103 - loss: 2.1975 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 20/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.1135 - loss: 2.1973 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 21/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.1104 - loss: 2.1973 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 22/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.1121 - loss: 2.1975 - val_accuracy: 0.1011 - val_loss: 2.1979
# Epoch 23/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 185s 2s/step - accuracy: 0.1047 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 24/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 198s 2s/step - accuracy: 0.1005 - loss: 2.1975 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 25/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.1056 - loss: 2.1975 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 26/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.1051 - loss: 2.1973 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 27/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.1106 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 28/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 242s 2s/step - accuracy: 0.1106 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 29/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 240s 2s/step - accuracy: 0.1109 - loss: 2.1974 - val_accuracy: 0.1067 - val_loss: 2.1979
# Epoch 30/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.1067 - loss: 2.1975 - val_accuracy: 0.1067 - val_loss: 2.1979

# %%
# Model 3 is the final Model.Using Augmented Data

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
## your code goes here
model_4 = Sequential()
model_4.add(layers.Rescaling(1./255,input_shape=(180,180,3))) 
model_4.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Conv2D(256,kernel_size=(11,11),activation='relu'))
model_4.add(layers.MaxPool2D(pool_size=(2,2)))
model_4.add(layers.Dropout(0.5))
model_4.add(layers.Flatten())
model_4.add(layers.Dense(256,activation='relu'))
model_4.add(layers.Dropout(0.25))
model_4.add(layers.Dense(128,activation='relu'))
model_4.add(layers.Dropout(0.25))
model_4.add(layers.Dense(64,activation='relu'))
model_4.add(layers.Dropout(0.25))
model_4.add(layers.Dense(len(class_names),activation='softmax'))

# %%
# View the summary of all layers
model_4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_3 (Rescaling)         │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 10, 10, 256)    │     3,965,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │     1,638,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 9)              │           585 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,738,825 (21.89 MB)
#  Trainable params: 5,738,825 (21.89 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
### Todo, choose an appropirate optimiser and loss function
### Todo, choose an appropirate optimiser and loss function
from tensorflow.keras.callbacks import ReduceLROnPlateau
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)
opt=tf.keras.optimizers.Adam()
model_4.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
#epochs = 30
## Your code goes here, use 50 epochs.
epochs = 30
history_4 = model_4.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 108s 906ms/step - accuracy: 0.1219 - loss: 2.2322 - val_accuracy: 0.1478 - val_loss: 2.1957
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 112s 996ms/step - accuracy: 0.1251 - loss: 2.1946 - val_accuracy: 0.1689 - val_loss: 2.0898
# Epoch 3/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 809ms/step - accuracy: 0.1739 - loss: 2.0453 - val_accuracy: 0.2033 - val_loss: 1.8721
# Epoch 4/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3562s 32s/step - accuracy: 0.2115 - loss: 1.8740 - val_accuracy: 0.2856 - val_loss: 1.7940
# Epoch 5/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 89s 792ms/step - accuracy: 0.2814 - loss: 1.7681 - val_accuracy: 0.2333 - val_loss: 1.7951
# Epoch 6/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 90s 794ms/step - accuracy: 0.2647 - loss: 1.8117 - val_accuracy: 0.2211 - val_loss: 1.8157
# Epoch 7/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2231s 20s/step - accuracy: 0.2468 - loss: 1.7989 - val_accuracy: 0.2967 - val_loss: 1.7100
# Epoch 8/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 808ms/step - accuracy: 0.2997 - loss: 1.6878 - val_accuracy: 0.2956 - val_loss: 1.7889
# Epoch 9/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 804ms/step - accuracy: 0.3317 - loss: 1.6775 - val_accuracy: 0.3278 - val_loss: 1.7075
# Epoch 10/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 632s 6s/step - accuracy: 0.3421 - loss: 1.6467 - val_accuracy: 0.3400 - val_loss: 1.6605
# Epoch 11/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 13106s 117s/step - accuracy: 0.3782 - loss: 1.5387 - val_accuracy: 0.4422 - val_loss: 1.4132
# Epoch 12/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 89s 783ms/step - accuracy: 0.4289 - loss: 1.4400 - val_accuracy: 0.4144 - val_loss: 1.5498
# Epoch 13/30
#   1/113 ━━━━━━━━━━━━━━━━━━━━ 1:16 686ms/step - accuracy: 0.4062 - loss: 1.5436

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history_4.history['accuracy']
val_acc = history_4.history['val_accuracy']

loss = history_4.history['loss']
val_loss = history_4.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
#
# The training accuracy and validation accuracy are almost same. This is a sign of good fit.
# The training loss and validation loss are almost same. This is a sign of good fit.
# The Validation accuracy is 0.87 which is good. The model is able to classify the images with 87% accuracy.

# %% [markdown]
# ## Test

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img, img_to_array
Test_image_path = os.path.join(data_dir_test, class_names[1], '*')
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model_4.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print(f"Actual Class: {class_names[1]}" + '\n' + "Predictive Class: " + pred_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# Actual Class: pigmented benign keratosis
# Predictive Class: pigmented benign keratosis

# %%
from tensorflow.keras import layers, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf

# Define model architecture
model_5 = Sequential()
model_5.add(layers.Rescaling(1./255, input_shape=(180, 180, 3))) 

# First Conv Block with Batch Normalization
model_5.add(layers.Conv2D(32, kernel_size=(3, 3), activation='relu'))
model_5.add(layers.BatchNormalization())
model_5.add(layers.MaxPool2D(pool_size=(2, 2)))

# Second Conv Block
model_5.add(layers.Conv2D(64, kernel_size=(3, 3), activation='relu'))
model_5.add(layers.BatchNormalization())
model_5.add(layers.MaxPool2D(pool_size=(2, 2)))

# Third Conv Block
model_5.add(layers.Conv2D(128, kernel_size=(3, 3), activation='relu'))
model_5.add(layers.BatchNormalization())
model_5.add(layers.MaxPool2D(pool_size=(2, 2)))

# Fourth Conv Block with a larger kernel
model_5.add(layers.Conv2D(256, kernel_size=(3, 3), activation='relu'))
model_5.add(layers.BatchNormalization())
model_5.add(layers.MaxPool2D(pool_size=(2, 2)))

# Flatten and Fully Connected Layers
model_5.add(layers.Flatten())
model_5.add(layers.Dense(256, activation='relu'))
model_5.add(layers.Dropout(0.3))

model_5.add(layers.Dense(128, activation='relu'))
model_5.add(layers.Dropout(0.3))

model_5.add(layers.Dense(64, activation='relu'))
model_5.add(layers.Dropout(0.2))

# Output layer
model_5.add(layers.Dense(len(class_names), activation='softmax'))

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=0.1, min_lr=1e-7)

# Compile the model
opt = tf.keras.optimizers.Adam()
model_5.compile(optimizer=opt,
                loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                metrics=['accuracy'])

# Fit the model
epochs = 30
history_5 = model_5.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 112s 922ms/step - accuracy: 0.1615 - loss: 3.9155 - val_accuracy: 0.0944 - val_loss: 2.3546 - learning_rate: 0.0010
# Epoch 2/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 98s 871ms/step - accuracy: 0.1704 - loss: 2.4305 - val_accuracy: 0.1178 - val_loss: 2.2377 - learning_rate: 0.0010
# Epoch 3/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 104s 921ms/step - accuracy: 0.2113 - loss: 2.1155 - val_accuracy: 0.1400 - val_loss: 2.1452 - learning_rate: 0.0010
# Epoch 4/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 101s 894ms/step - accuracy: 0.2534 - loss: 1.9282 - val_accuracy: 0.1333 - val_loss: 2.2301 - learning_rate: 0.0010
# Epoch 5/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 102s 899ms/step - accuracy: 0.2778 - loss: 1.8535 - val_accuracy: 0.2078 - val_loss: 2.2571 - learning_rate: 0.0010
# Epoch 6/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.2964 - loss: 1.8034 - val_accuracy: 0.3033 - val_loss: 2.2508 - learning_rate: 0.0010
# Epoch 7/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.3333 - loss: 1.7272 - val_accuracy: 0.3122 - val_loss: 1.8785 - learning_rate: 0.0010
# Epoch 8/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 322s 3s/step - accuracy: 0.3568 - loss: 1.6182 - val_accuracy: 0.4133 - val_loss: 1.5056 - learning_rate: 0.0010
# Epoch 9/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.3620 - loss: 1.5758 - val_accuracy: 0.4444 - val_loss: 1.4151 - learning_rate: 0.0010
# Epoch 10/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 98s 871ms/step - accuracy: 0.4218 - loss: 1.4716 - val_accuracy: 0.3611 - val_loss: 1.6690 - learning_rate: 0.0010
# Epoch 11/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 100s 884ms/step - accuracy: 0.4373 - loss: 1.4537 - val_accuracy: 0.2856 - val_loss: 1.9657 - learning_rate: 0.0010
# Epoch 12/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 101s 894ms/step - accuracy: 0.4203 - loss: 1.4410 - val_accuracy: 0.4589 - val_loss: 1.4063 - learning_rate: 0.0010
# Epoch 13/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 103s 913ms/step - accuracy: 0.4465 - loss: 1.3865 - val_accuracy: 0.5000 - val_loss: 1.3188 - learning_rate: 0.0010
# Epoch 14/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 104s 919ms/step - accuracy: 0.4868 - loss: 1.3161 - val_accuracy: 0.3700 - val_loss: 2.0077 - learning_rate: 0.0010
# Epoch 15/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 109s 960ms/step - accuracy: 0.5209 - loss: 1.2117 - val_accuracy: 0.5167 - val_loss: 1.2516 - learning_rate: 0.0010
# Epoch 16/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 100s 880ms/step - accuracy: 0.5221 - loss: 1.1963 - val_accuracy: 0.4922 - val_loss: 1.3630 - learning_rate: 0.0010
# Epoch 17/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 101s 893ms/step - accuracy: 0.5551 - loss: 1.1348 - val_accuracy: 0.5356 - val_loss: 1.3131 - learning_rate: 0.0010
# Epoch 18/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 97s 863ms/step - accuracy: 0.5636 - loss: 1.0756 - val_accuracy: 0.6067 - val_loss: 1.0564 - learning_rate: 0.0010
# Epoch 19/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1914s 17s/step - accuracy: 0.6193 - loss: 1.0145 - val_accuracy: 0.5878 - val_loss: 1.1278 - learning_rate: 0.0010
# Epoch 20/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 93s 826ms/step - accuracy: 0.6308 - loss: 0.9435 - val_accuracy: 0.5567 - val_loss: 1.2010 - learning_rate: 0.0010
# Epoch 21/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 90s 801ms/step - accuracy: 0.6637 - loss: 0.8834 - val_accuracy: 0.5733 - val_loss: 1.2654 - learning_rate: 0.0010
# Epoch 22/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 103s 911ms/step - accuracy: 0.6678 - loss: 0.8606 - val_accuracy: 0.6744 - val_loss: 0.8593 - learning_rate: 0.0010
# Epoch 23/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 93s 826ms/step - accuracy: 0.7028 - loss: 0.7714 - val_accuracy: 0.6678 - val_loss: 0.9135 - learning_rate: 0.0010
# Epoch 24/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 101s 894ms/step - accuracy: 0.7149 - loss: 0.7310 - val_accuracy: 0.5878 - val_loss: 1.3326 - learning_rate: 0.0010
# Epoch 25/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 96s 853ms/step - accuracy: 0.7627 - loss: 0.6418 - val_accuracy: 0.6511 - val_loss: 1.0409 - learning_rate: 0.0010
# Epoch 26/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 804ms/step - accuracy: 0.7724 - loss: 0.6154 - val_accuracy: 0.7444 - val_loss: 0.6899 - learning_rate: 0.0010
# Epoch 27/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 90s 798ms/step - accuracy: 0.7853 - loss: 0.5582 - val_accuracy: 0.6500 - val_loss: 1.0227 - learning_rate: 0.0010
# Epoch 28/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 90s 800ms/step - accuracy: 0.8039 - loss: 0.5163 - val_accuracy: 0.6722 - val_loss: 1.0243 - learning_rate: 0.0010
# Epoch 29/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 810ms/step - accuracy: 0.8138 - loss: 0.4774 - val_accuracy: 0.6522 - val_loss: 1.1420 - learning_rate: 0.0010
# Epoch 30/30
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 91s 801ms/step - accuracy: 0.8384 - loss: 0.4286 - val_accuracy: 0.7222 - val_loss: 0.8954 - learning_rate: 0.0010

# %%
acc = history_5.history['accuracy']
val_acc = history_5.history['val_accuracy']

loss = history_5.history['loss']
val_loss = history_5.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
class_names
# Out:
# ['melanoma',
#  'pigmented benign keratosis',
#  'nevus',
#  'basal cell carcinoma',
#  'actinic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion',
#  'seborrheic keratosis',
#  'dermatofibroma']

# %%
from glob import glob
from tensorflow.keras.preprocessing.image import load_img, img_to_array

Test_image_path = os.path.join(data_dir_test, class_names[0], '*')
print(Test_image_path)
Test_image = glob(Test_image_path)
Test_image = load_img(Test_image[-1],target_size=(180,180,3))
plt.imshow(Test_image)
plt.grid(False)

img = np.expand_dims(Test_image,axis=0)
pred = model_5.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print(f"Actual Class: {class_names[0]}" + '\n' + "Predictive Class: " + pred_class)
# Out:
# data/Test/melanoma/*
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Actual Class: melanoma
# Predictive Class: melanoma
